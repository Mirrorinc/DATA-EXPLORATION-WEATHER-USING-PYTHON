# %%
import pandas as pd
import openpyxl

# %%
data = pd.read_excel(r"C:\Users\Mirror\Desktop\WeatherEventsDatasets.xlsx")

# %%
data
# Out:
#     EventId  Type Severity      StartTime(UTC)        EndTime(UTC)  \
# 0       W-1  Snow    Light 2016-01-06 23:14:00 2016-01-07 00:34:00
# 1       W-2  Snow    Light 2016-01-07 04:14:00 2016-01-07 04:54:00
# 2       W-3  Snow    Light 2016-01-07 05:54:00 2016-01-07 15:34:00
# 3       W-4  Snow    Light 2016-01-08 05:34:00 2016-01-08 05:54:00
# 4       W-5  Snow    Light 2016-01-08 13:54:00 2016-01-08 15:54:00
# ..      ...   ...      ...                 ...                 ...
# 295   W-296  Rain    Light 2016-07-03 01:16:00 2016-07-03 01:36:00
# 296   W-297  Rain    Light 2016-07-03 02:36:00 2016-07-03 03:56:00
# 297   W-298  Rain    Light 2016-07-03 20:36:00 2016-07-03 20:56:00
# 298   W-299  Rain    Light 2016-07-03 21:16:00 2016-07-03 22:36:00
# 299   W-300  Rain    Light 2016-07-03 23:36:00 2016-07-04 00:16:00
#
#      Precipitation(in)     TimeZone AirportCode  LocationLat  LocationLng  \
# 0                 0.00  US/Mountain        K04V      38.0972    -106.1689
# ...

# %%
data.head()
# Out:
#   EventId  Type Severity      StartTime(UTC)        EndTime(UTC)  \
# 0     W-1  Snow    Light 2016-01-06 23:14:00 2016-01-07 00:34:00
# 1     W-2  Snow    Light 2016-01-07 04:14:00 2016-01-07 04:54:00
# 2     W-3  Snow    Light 2016-01-07 05:54:00 2016-01-07 15:34:00
# 3     W-4  Snow    Light 2016-01-08 05:34:00 2016-01-08 05:54:00
# 4     W-5  Snow    Light 2016-01-08 13:54:00 2016-01-08 15:54:00
#
#    Precipitation(in)     TimeZone AirportCode  LocationLat  LocationLng  \
# 0               0.00  US/Mountain        K04V      38.0972    -106.1689
# 1               0.00  US/Mountain        K04V      38.0972    -106.1689
# 2               0.03  US/Mountain        K04V      38.0972    -106.1689
# 3               0.00  US/Mountain        K04V      38.0972    -106.1689
# 4               0.00  US/Mountain        K04V      38.0972    -106.1689
#
#        City    County State  ZipCode
# 0  Saguache  Saguache    CO    81149
# 1  Saguache  Saguache    CO    81149
# ...

# %%
data.shape
# Out:
# (300, 14)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=300, step=1)

# %%
data.columns
# Out:
# Index(['EventId', 'Type', 'Severity', 'StartTime(UTC)', 'EndTime(UTC)',
#        'Precipitation(in)', 'TimeZone', 'AirportCode', 'LocationLat',
#        'LocationLng', 'City', 'County', 'State', 'ZipCode'],
#       dtype='object')

# %%
data.dtypes
# Out:
# EventId                      object
# Type                         object
# Severity                     object
# StartTime(UTC)       datetime64[ns]
# EndTime(UTC)         datetime64[ns]
# Precipitation(in)           float64
# TimeZone                     object
# AirportCode                  object
# LocationLat                 float64
# LocationLng                 float64
# City                         object
# County                       object
# State                        object
# ZipCode                       int64
# dtype: object

# %%
data.nunique()
# Out:
# EventId              300
# Type                   5
# Severity               4
# StartTime(UTC)       300
# EndTime(UTC)         300
# Precipitation(in)     15
# TimeZone               1
# AirportCode            1
# LocationLat            1
# LocationLng            1
# City                   1
# County                 1
# State                  1
# ZipCode                1
# dtype: int64

# %%
data.count
# Out:
# <bound method DataFrame.count of     EventId  Type Severity      StartTime(UTC)        EndTime(UTC)  \
# 0       W-1  Snow    Light 2016-01-06 23:14:00 2016-01-07 00:34:00
# 1       W-2  Snow    Light 2016-01-07 04:14:00 2016-01-07 04:54:00
# 2       W-3  Snow    Light 2016-01-07 05:54:00 2016-01-07 15:34:00
# 3       W-4  Snow    Light 2016-01-08 05:34:00 2016-01-08 05:54:00
# 4       W-5  Snow    Light 2016-01-08 13:54:00 2016-01-08 15:54:00
# ..      ...   ...      ...                 ...                 ...
# 295   W-296  Rain    Light 2016-07-03 01:16:00 2016-07-03 01:36:00
# 296   W-297  Rain    Light 2016-07-03 02:36:00 2016-07-03 03:56:00
# 297   W-298  Rain    Light 2016-07-03 20:36:00 2016-07-03 20:56:00
# 298   W-299  Rain    Light 2016-07-03 21:16:00 2016-07-03 22:36:00
# 299   W-300  Rain    Light 2016-07-03 23:36:00 2016-07-04 00:16:00
#
#      Precipitation(in)     TimeZone AirportCode  LocationLat  LocationLng  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   EventId            300 non-null    object
#  1   Type               300 non-null    object
#  2   Severity           300 non-null    object
#  3   StartTime(UTC)     300 non-null    datetime64[ns]
#  4   EndTime(UTC)       300 non-null    datetime64[ns]
#  5   Precipitation(in)  300 non-null    float64
#  6   TimeZone           300 non-null    object
#  7   AirportCode        300 non-null    object
#  8   LocationLat        300 non-null    float64
#  9   LocationLng        300 non-null    float64
#  10  City               300 non-null    object
#  11  County             300 non-null    object
#  12  State              300 non-null    object
#  13  ZipCode            300 non-null    int64
# dtypes: datetime64[ns](2), float64(3), int64(1), object(8)
# memory usage: 32.9+ KB

# %%
data['Severity'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      Light
# 1      Light
# 2      Light
# 3      Light
# 4      Light
#        ...
# 295    Light
# 296    Light
# 297    Light
# 298    Light
# 299    Light
# Name: Severity, Length: 300, dtype: object>

# %%
data['Severity'].nunique()
# Out:
# 4

# %%
data['Severity'].unique()
# Out:
# array(['Light', 'Severe', 'Moderate', 'Heavy'], dtype=object)

# %% [markdown]
# **TO GET THE PICTURE OF THE WEATHER DATASET WHEN THE 'WEATHER IS EXACTLY RAINY'**

# %%
data.Type.value_counts()
# Out:
# Type
# Rain     170
# Snow     103
# Fog       11
# Storm     11
# Cold       5
# Name: count, dtype: int64

# %%
#By Filtering
data[data.Type == 'Rain']
# Out:
#     EventId  Type Severity      StartTime(UTC)        EndTime(UTC)  \
# 51     W-52  Rain    Light 2016-02-19 04:34:00 2016-02-19 05:14:00
# 82     W-83  Rain    Light 2016-04-09 20:55:00 2016-04-09 21:15:00
# 83     W-84  Rain    Light 2016-04-09 22:55:00 2016-04-10 00:15:00
# 84     W-85  Rain    Light 2016-04-11 06:15:00 2016-04-11 06:35:00
# 85     W-86  Rain    Light 2016-04-11 21:55:00 2016-04-11 22:15:00
# ..      ...   ...      ...                 ...                 ...
# 295   W-296  Rain    Light 2016-07-03 01:16:00 2016-07-03 01:36:00
# 296   W-297  Rain    Light 2016-07-03 02:36:00 2016-07-03 03:56:00
# 297   W-298  Rain    Light 2016-07-03 20:36:00 2016-07-03 20:56:00
# 298   W-299  Rain    Light 2016-07-03 21:16:00 2016-07-03 22:36:00
# 299   W-300  Rain    Light 2016-07-03 23:36:00 2016-07-04 00:16:00
#
#      Precipitation(in)     TimeZone AirportCode  LocationLat  LocationLng  \
# 51                0.00  US/Mountain        K04V      38.0972    -106.1689
# ...

# %% [markdown]
# **TO GET THE NUMBER OF TIMES WHEN THE PRECIPITATION IS EXACTLY 0.03**

# %%
#Trying to rename the Precipitation(in) column to precitation only
data.rename(columns={'Precipitation(in)': 'Precipitation'}, inplace=True)

# %%
data
# Out:
#     EventId  Type Severity      StartTime(UTC)        EndTime(UTC)  \
# 0       W-1  Snow    Light 2016-01-06 23:14:00 2016-01-07 00:34:00
# 1       W-2  Snow    Light 2016-01-07 04:14:00 2016-01-07 04:54:00
# 2       W-3  Snow    Light 2016-01-07 05:54:00 2016-01-07 15:34:00
# 3       W-4  Snow    Light 2016-01-08 05:34:00 2016-01-08 05:54:00
# 4       W-5  Snow    Light 2016-01-08 13:54:00 2016-01-08 15:54:00
# ..      ...   ...      ...                 ...                 ...
# 295   W-296  Rain    Light 2016-07-03 01:16:00 2016-07-03 01:36:00
# 296   W-297  Rain    Light 2016-07-03 02:36:00 2016-07-03 03:56:00
# 297   W-298  Rain    Light 2016-07-03 20:36:00 2016-07-03 20:56:00
# 298   W-299  Rain    Light 2016-07-03 21:16:00 2016-07-03 22:36:00
# 299   W-300  Rain    Light 2016-07-03 23:36:00 2016-07-04 00:16:00
#
#      Precipitation     TimeZone AirportCode  LocationLat  LocationLng  \
# 0             0.00  US/Mountain        K04V      38.0972    -106.1689
# ...

# %%
data[data.Precipitation == 0.03 ]
# Out:
#     EventId  Type  Severity      StartTime(UTC)        EndTime(UTC)  \
# 2       W-3  Snow     Light 2016-01-07 05:54:00 2016-01-07 15:34:00
# 42     W-43  Snow     Light 2016-02-01 05:35:00 2016-02-01 07:35:00
# 54     W-55  Snow     Light 2016-02-23 06:14:00 2016-02-23 07:14:00
# 100   W-101  Snow     Light 2016-04-16 09:35:00 2016-04-16 10:15:00
# 101   W-102  Snow  Moderate 2016-04-16 10:15:00 2016-04-16 10:35:00
# 103   W-104  Snow     Light 2016-04-16 11:15:00 2016-04-16 14:35:00
# 136   W-137  Rain     Light 2016-04-29 04:35:00 2016-04-29 06:15:00
# 156   W-157  Snow     Light 2016-04-30 00:15:00 2016-04-30 01:35:00
# 158   W-159  Snow     Light 2016-04-30 02:15:00 2016-04-30 03:55:00
#
#      Precipitation     TimeZone AirportCode  LocationLat  LocationLng  \
# 2             0.03  US/Mountain        K04V      38.0972    -106.1689
# 42            0.03  US/Mountain        K04V      38.0972    -106.1689
# 54            0.03  US/Mountain        K04V      38.0972    -106.1689
# ...

# %% [markdown]
# **TO CHEECK OUT NULL VALUES**

# %%
data.isnull().sum()
# Out:
# EventId           0
# Type              0
# Severity          0
# StartTime(UTC)    0
# EndTime(UTC)      0
# Precipitation     0
# TimeZone          0
# AirportCode       0
# LocationLat       0
# LocationLng       0
# City              0
# County            0
# State             0
# ZipCode           0
# dtype: int64

# %% [markdown]
# **TO CHECK CASES WHEN PRECIPITATION IS 0.03 AND SEVERITY IS SEVERE**

# %%
data[(data['Precipitation'] == 0.03) & (data['Severity'] == 'Severe')]

#FROM THE RESULT, THERE ARE NO SUCH CASES
# Out:
# Empty DataFrame
# Columns: [EventId, Type, Severity, StartTime(UTC), EndTime(UTC), Precipitation, TimeZone, AirportCode, LocationLat, LocationLng, City, County, State, ZipCode]
# Index: []

# %% [markdown]
# **TO CHECK THE DIFFERENCE IN MINUTES BETWEEN THE STARTTIME(UTC) AND ENDTIME(UTC), THIS GIVE US NUMBER OF MINUTES IT TAKES FOR WEATHER CHANGE**

# %%
#Renaming column "StartTime(UTC)" to "StartTime_UTC" and same to EndTime(UTC)
data.rename(columns={'StartTime(UTC)': 'StartTime_UTC'}, inplace=True)

# %%
data
# Out:
#     EventId  Type Severity       StartTime_UTC        EndTime(UTC)  \
# 0       W-1  Snow    Light 2016-01-06 23:14:00 2016-01-07 00:34:00
# 1       W-2  Snow    Light 2016-01-07 04:14:00 2016-01-07 04:54:00
# 2       W-3  Snow    Light 2016-01-07 05:54:00 2016-01-07 15:34:00
# 3       W-4  Snow    Light 2016-01-08 05:34:00 2016-01-08 05:54:00
# 4       W-5  Snow    Light 2016-01-08 13:54:00 2016-01-08 15:54:00
# ..      ...   ...      ...                 ...                 ...
# 295   W-296  Rain    Light 2016-07-03 01:16:00 2016-07-03 01:36:00
# 296   W-297  Rain    Light 2016-07-03 02:36:00 2016-07-03 03:56:00
# 297   W-298  Rain    Light 2016-07-03 20:36:00 2016-07-03 20:56:00
# 298   W-299  Rain    Light 2016-07-03 21:16:00 2016-07-03 22:36:00
# 299   W-300  Rain    Light 2016-07-03 23:36:00 2016-07-04 00:16:00
#
#      Precipitation     TimeZone AirportCode  LocationLat  LocationLng  \
# 0             0.00  US/Mountain        K04V      38.0972    -106.1689
# ...

# %%
data.rename(columns={'EndTime(UTC)': 'EndTime_UTC'}, inplace=True)

# %%
data
# Out:
#     EventId  Type Severity       StartTime_UTC         EndTime_UTC  \
# 0       W-1  Snow    Light 2016-01-06 23:14:00 2016-01-07 00:34:00
# 1       W-2  Snow    Light 2016-01-07 04:14:00 2016-01-07 04:54:00
# 2       W-3  Snow    Light 2016-01-07 05:54:00 2016-01-07 15:34:00
# 3       W-4  Snow    Light 2016-01-08 05:34:00 2016-01-08 05:54:00
# 4       W-5  Snow    Light 2016-01-08 13:54:00 2016-01-08 15:54:00
# ..      ...   ...      ...                 ...                 ...
# 295   W-296  Rain    Light 2016-07-03 01:16:00 2016-07-03 01:36:00
# 296   W-297  Rain    Light 2016-07-03 02:36:00 2016-07-03 03:56:00
# 297   W-298  Rain    Light 2016-07-03 20:36:00 2016-07-03 20:56:00
# 298   W-299  Rain    Light 2016-07-03 21:16:00 2016-07-03 22:36:00
# 299   W-300  Rain    Light 2016-07-03 23:36:00 2016-07-04 00:16:00
#
#      Precipitation     TimeZone AirportCode  LocationLat  LocationLng  \
# 0             0.00  US/Mountain        K04V      38.0972    -106.1689
# ...

# %%
import pandas as pd

df = pd.DataFrame(data)

# Calculate the time difference in minutes
df['TimeDifference_minutes'] = (df['EndTime_UTC'] - df['StartTime_UTC']).dt.total_seconds() / 60

print(df)
# Out:
#     EventId  Type Severity       StartTime_UTC         EndTime_UTC  \
# 0       W-1  Snow    Light 2016-01-06 23:14:00 2016-01-07 00:34:00
# 1       W-2  Snow    Light 2016-01-07 04:14:00 2016-01-07 04:54:00
# 2       W-3  Snow    Light 2016-01-07 05:54:00 2016-01-07 15:34:00
# 3       W-4  Snow    Light 2016-01-08 05:34:00 2016-01-08 05:54:00
# 4       W-5  Snow    Light 2016-01-08 13:54:00 2016-01-08 15:54:00
# ..      ...   ...      ...                 ...                 ...
# 295   W-296  Rain    Light 2016-07-03 01:16:00 2016-07-03 01:36:00
# 296   W-297  Rain    Light 2016-07-03 02:36:00 2016-07-03 03:56:00
# 297   W-298  Rain    Light 2016-07-03 20:36:00 2016-07-03 20:56:00
# 298   W-299  Rain    Light 2016-07-03 21:16:00 2016-07-03 22:36:00
# 299   W-300  Rain    Light 2016-07-03 23:36:00 2016-07-04 00:16:00
#
#      Precipitation     TimeZone AirportCode  LocationLat  LocationLng  \
# 0             0.00  US/Mountain        K04V      38.0972    -106.1689
# ...
